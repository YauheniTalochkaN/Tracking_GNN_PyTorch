# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# %%
def calc_dphi(phi1, phi2):
    dphi = phi2 - phi1
    dphi[dphi > np.pi] -= 2*np.pi
    dphi[dphi < -np.pi] += 2*np.pi
    return dphi

# %%
input_dir = './MPD_dataset/MPD_events'
rmaxlist = []
zminlist = []
zmaxlist = []
maxrowlist = []
minrowlist = []
particlenumlist = []
hitnumlist = []

dphi_list = []
distance_list = []
dtheta_list = []
z0_list = []

pt = []

for evtid in range(1000):
    event_name = input_dir + f'/event_{evtid}_'
    print(f'Processing: {event_name:s}')

    hits = pd.read_csv(event_name + 'hits.csv')
    if not hits.empty:
        r = np.sqrt(hits.x**2 + hits.y**2)
        phi = np.arctan2(hits.y, hits.x)
        hits = hits[['hit_id', 'z', 'row_id', 'sector_id']].assign(r=r, phi=phi)
        rmaxlist.append(hits['r'].max())
        zminlist.append(hits['z'].min())
        zmaxlist.append(hits['z'].max())
        minrowlist.append(hits['row_id'].min())
        maxrowlist.append(hits['row_id'].max())
        hitnumlist.append(len(hits))

    tracks = pd.read_csv(event_name + 'tracks.csv')
    if not tracks.empty:
        particlenumlist.append(len(set(tracks['track_id'])))

    """truth = pd.read_csv(event_name + 'truth.csv')

    truth = truth.merge(tracks[['track_id', 'pt', 'mother_id']], on='track_id')
    hits = hits.merge(truth, on='hit_id')

    pt.append(len(hits[(hits['pt'] < 0.1) & (hits['mother_id'] == -1)]) / (len(hits[hits['mother_id'] == -1]) + 1e-8))

    hits = hits[(hits['pt'] >= 0.1) & (hits['mother_id'] == -1)]

    hit_gropus = hits.groupby("track_id")

    for x in set(hits['track_id']):
        track_df = hit_gropus.get_group(x).assign(evtid=evtid)
        if len(track_df) > 1:
            hit_pairs = track_df.reset_index().merge(track_df.reset_index(), on='evtid', suffixes=('_1', '_2'))
            hit_pairs = hit_pairs[(hit_pairs['row_id_1'] == hit_pairs['row_id_2'] - 1) & (hit_pairs['sector_id_1'] == hit_pairs['sector_id_2'])]

            if not hit_pairs.empty:
                dphi = calc_dphi(hit_pairs.phi_1, hit_pairs.phi_2)
                dz = hit_pairs.z_2 - hit_pairs.z_1
                dr = hit_pairs.r_2 - hit_pairs.r_1
                z0 = hit_pairs.z_1 - hit_pairs.r_1 * dz / dr
                distance = np.sqrt(hit_pairs.r_1**2 + hit_pairs.r_2**2 - 2 * hit_pairs.r_1 * hit_pairs.r_2 * np.cos(dphi) + dz**2)
                theta = np.arctan(dz / dr)

                dphi_list.append(dphi.abs().max())
                distance_list.append(distance.abs().max())
                dtheta_list.append(theta.abs().max())
                z0_list.append(z0.abs().max()) """
# Out:
# Processing: ./MPD_dataset/MPD_events/event_0_
# Processing: ./MPD_dataset/MPD_events/event_1_
# Processing: ./MPD_dataset/MPD_events/event_2_
# Processing: ./MPD_dataset/MPD_events/event_3_
# Processing: ./MPD_dataset/MPD_events/event_4_
# Processing: ./MPD_dataset/MPD_events/event_5_
# Processing: ./MPD_dataset/MPD_events/event_6_
# Processing: ./MPD_dataset/MPD_events/event_7_
# Processing: ./MPD_dataset/MPD_events/event_8_
# Processing: ./MPD_dataset/MPD_events/event_9_
# Processing: ./MPD_dataset/MPD_events/event_10_
# Processing: ./MPD_dataset/MPD_events/event_11_
# Processing: ./MPD_dataset/MPD_events/event_12_
# Processing: ./MPD_dataset/MPD_events/event_13_
# Processing: ./MPD_dataset/MPD_events/event_14_
# Processing: ./MPD_dataset/MPD_events/event_15_
# Processing: ./MPD_dataset/MPD_events/event_16_
# Processing: ./MPD_dataset/MPD_events/event_17_
# Processing: ./MPD_dataset/MPD_events/event_18_
# Processing: ./MPD_dataset/MPD_events/event_19_
# Processing: ./MPD_dataset/MPD_events/event_20_
# Processing: ./MPD_dataset/MPD_events/event_21_
# Processing: ./MPD_dataset/MPD_events/event_22_
# Processing: ./MPD_dataset/MPD_events/event_23_
# Processing: ./MPD_dataset/MPD_events/event_24_
# Processing: ./MPD_dataset/MPD_events/event_25_
# Processing: ./MPD_dataset/MPD_events/event_26_
# Processing: ./MPD_dataset/MPD_events/event_27_
# Processing: ./MPD_dataset/MPD_events/event_28_
# Processing: ./MPD_dataset/MPD_events/event_29_
# Processing: ./MPD_dataset/MPD_events/event_30_
# Processing: ./MPD_dataset/MPD_events/event_31_
# Processing: ./MPD_dataset/MPD_events/event_32_
# Processing: ./MPD_dataset/MPD_events/event_33_
# Processing: ./MPD_dataset/MPD_events/event_34_
# Processing: ./MPD_dataset/MPD_events/event_35_
# Processing: ./MPD_dataset/MPD_events/event_36_
# Processing: ./MPD_dataset/MPD_events/event_37_
# Processing: ./MPD_dataset/MPD_events/event_38_
# Processing: ./MPD_dataset/MPD_events/event_39_
# Processing: ./MPD_dataset/MPD_events/event_40_
# Processing: ./MPD_dataset/MPD_events/event_41_
# Processing: ./MPD_dataset/MPD_events/event_42_
# Processing: ./MPD_dataset/MPD_events/event_43_
# Processing: ./MPD_dataset/MPD_events/event_44_
# Processing: ./MPD_dataset/MPD_events/event_45_
# Processing: ./MPD_dataset/MPD_events/event_46_
# Processing: ./MPD_dataset/MPD_events/event_47_
# Processing: ./MPD_dataset/MPD_events/event_48_
# Processing: ./MPD_dataset/MPD_events/event_49_
# Processing: ./MPD_dataset/MPD_events/event_50_
# Processing: ./MPD_dataset/MPD_events/event_51_
# Processing: ./MPD_dataset/MPD_events/event_52_
# Processing: ./MPD_dataset/MPD_events/event_53_
# Processing: ./MPD_dataset/MPD_events/event_54_
# Processing: ./MPD_dataset/MPD_events/event_55_
# Processing: ./MPD_dataset/MPD_events/event_56_
# Processing: ./MPD_dataset/MPD_events/event_57_
# Processing: ./MPD_dataset/MPD_events/event_58_
# Processing: ./MPD_dataset/MPD_events/event_59_
# Processing: ./MPD_dataset/MPD_events/event_60_
# Processing: ./MPD_dataset/MPD_events/event_61_
# Processing: ./MPD_dataset/MPD_events/event_62_
# Processing: ./MPD_dataset/MPD_events/event_63_
# Processing: ./MPD_dataset/MPD_events/event_64_
# Processing: ./MPD_dataset/MPD_events/event_65_
# Processing: ./MPD_dataset/MPD_events/event_66_
# Processing: ./MPD_dataset/MPD_events/event_67_
# Processing: ./MPD_dataset/MPD_events/event_68_
# Processing: ./MPD_dataset/MPD_events/event_69_
# Processing: ./MPD_dataset/MPD_events/event_70_
# Processing: ./MPD_dataset/MPD_events/event_71_
# Processing: ./MPD_dataset/MPD_events/event_72_
# Processing: ./MPD_dataset/MPD_events/event_73_
# Processing: ./MPD_dataset/MPD_events/event_74_
# Processing: ./MPD_dataset/MPD_events/event_75_
# Processing: ./MPD_dataset/MPD_events/event_76_
# Processing: ./MPD_dataset/MPD_events/event_77_
# Processing: ./MPD_dataset/MPD_events/event_78_
# Processing: ./MPD_dataset/MPD_events/event_79_
# Processing: ./MPD_dataset/MPD_events/event_80_
# Processing: ./MPD_dataset/MPD_events/event_81_
# Processing: ./MPD_dataset/MPD_events/event_82_
# Processing: ./MPD_dataset/MPD_events/event_83_
# Processing: ./MPD_dataset/MPD_events/event_84_
# Processing: ./MPD_dataset/MPD_events/event_85_
# Processing: ./MPD_dataset/MPD_events/event_86_
# Processing: ./MPD_dataset/MPD_events/event_87_
# Processing: ./MPD_dataset/MPD_events/event_88_
# Processing: ./MPD_dataset/MPD_events/event_89_
# Processing: ./MPD_dataset/MPD_events/event_90_
# Processing: ./MPD_dataset/MPD_events/event_91_
# Processing: ./MPD_dataset/MPD_events/event_92_
# Processing: ./MPD_dataset/MPD_events/event_93_
# Processing: ./MPD_dataset/MPD_events/event_94_
# Processing: ./MPD_dataset/MPD_events/event_95_
# Processing: ./MPD_dataset/MPD_events/event_96_
# Processing: ./MPD_dataset/MPD_events/event_97_
# Processing: ./MPD_dataset/MPD_events/event_98_
# Processing: ./MPD_dataset/MPD_events/event_99_
# Processing: ./MPD_dataset/MPD_events/event_100_
# Processing: ./MPD_dataset/MPD_events/event_101_
# Processing: ./MPD_dataset/MPD_events/event_102_
# Processing: ./MPD_dataset/MPD_events/event_103_
# Processing: ./MPD_dataset/MPD_events/event_104_
# Processing: ./MPD_dataset/MPD_events/event_105_
# Processing: ./MPD_dataset/MPD_events/event_106_
# Processing: ./MPD_dataset/MPD_events/event_107_
# Processing: ./MPD_dataset/MPD_events/event_108_
# Processing: ./MPD_dataset/MPD_events/event_109_
# Processing: ./MPD_dataset/MPD_events/event_110_
# Processing: ./MPD_dataset/MPD_events/event_111_
# Processing: ./MPD_dataset/MPD_events/event_112_
# Processing: ./MPD_dataset/MPD_events/event_113_
# Processing: ./MPD_dataset/MPD_events/event_114_
# Processing: ./MPD_dataset/MPD_events/event_115_
# Processing: ./MPD_dataset/MPD_events/event_116_
# Processing: ./MPD_dataset/MPD_events/event_117_
# Processing: ./MPD_dataset/MPD_events/event_118_
# Processing: ./MPD_dataset/MPD_events/event_119_
# Processing: ./MPD_dataset/MPD_events/event_120_
# Processing: ./MPD_dataset/MPD_events/event_121_
# Processing: ./MPD_dataset/MPD_events/event_122_
# Processing: ./MPD_dataset/MPD_events/event_123_
# Processing: ./MPD_dataset/MPD_events/event_124_
# Processing: ./MPD_dataset/MPD_events/event_125_
# Processing: ./MPD_dataset/MPD_events/event_126_
# Processing: ./MPD_dataset/MPD_events/event_127_
# Processing: ./MPD_dataset/MPD_events/event_128_
# Processing: ./MPD_dataset/MPD_events/event_129_
# Processing: ./MPD_dataset/MPD_events/event_130_
# Processing: ./MPD_dataset/MPD_events/event_131_
# Processing: ./MPD_dataset/MPD_events/event_132_
# Processing: ./MPD_dataset/MPD_events/event_133_
# Processing: ./MPD_dataset/MPD_events/event_134_
# Processing: ./MPD_dataset/MPD_events/event_135_
# Processing: ./MPD_dataset/MPD_events/event_136_
# Processing: ./MPD_dataset/MPD_events/event_137_
# Processing: ./MPD_dataset/MPD_events/event_138_
# Processing: ./MPD_dataset/MPD_events/event_139_
# Processing: ./MPD_dataset/MPD_events/event_140_
# Processing: ./MPD_dataset/MPD_events/event_141_
# Processing: ./MPD_dataset/MPD_events/event_142_
# Processing: ./MPD_dataset/MPD_events/event_143_
# Processing: ./MPD_dataset/MPD_events/event_144_
# Processing: ./MPD_dataset/MPD_events/event_145_
# Processing: ./MPD_dataset/MPD_events/event_146_
# Processing: ./MPD_dataset/MPD_events/event_147_
# Processing: ./MPD_dataset/MPD_events/event_148_
# Processing: ./MPD_dataset/MPD_events/event_149_
# Processing: ./MPD_dataset/MPD_events/event_150_
# Processing: ./MPD_dataset/MPD_events/event_151_
# Processing: ./MPD_dataset/MPD_events/event_152_
# Processing: ./MPD_dataset/MPD_events/event_153_
# Processing: ./MPD_dataset/MPD_events/event_154_
# Processing: ./MPD_dataset/MPD_events/event_155_
# Processing: ./MPD_dataset/MPD_events/event_156_
# Processing: ./MPD_dataset/MPD_events/event_157_
# Processing: ./MPD_dataset/MPD_events/event_158_
# Processing: ./MPD_dataset/MPD_events/event_159_
# Processing: ./MPD_dataset/MPD_events/event_160_
# Processing: ./MPD_dataset/MPD_events/event_161_
# Processing: ./MPD_dataset/MPD_events/event_162_
# Processing: ./MPD_dataset/MPD_events/event_163_
# Processing: ./MPD_dataset/MPD_events/event_164_
# Processing: ./MPD_dataset/MPD_events/event_165_
# Processing: ./MPD_dataset/MPD_events/event_166_
# Processing: ./MPD_dataset/MPD_events/event_167_
# Processing: ./MPD_dataset/MPD_events/event_168_
# Processing: ./MPD_dataset/MPD_events/event_169_
# Processing: ./MPD_dataset/MPD_events/event_170_
# Processing: ./MPD_dataset/MPD_events/event_171_
# Processing: ./MPD_dataset/MPD_events/event_172_
# Processing: ./MPD_dataset/MPD_events/event_173_
# Processing: ./MPD_dataset/MPD_events/event_174_
# Processing: ./MPD_dataset/MPD_events/event_175_
# Processing: ./MPD_dataset/MPD_events/event_176_
# Processing: ./MPD_dataset/MPD_events/event_177_
# Processing: ./MPD_dataset/MPD_events/event_178_
# Processing: ./MPD_dataset/MPD_events/event_179_
# Processing: ./MPD_dataset/MPD_events/event_180_
# Processing: ./MPD_dataset/MPD_events/event_181_
# Processing: ./MPD_dataset/MPD_events/event_182_
# Processing: ./MPD_dataset/MPD_events/event_183_
# Processing: ./MPD_dataset/MPD_events/event_184_
# Processing: ./MPD_dataset/MPD_events/event_185_
# Processing: ./MPD_dataset/MPD_events/event_186_
# Processing: ./MPD_dataset/MPD_events/event_187_
# Processing: ./MPD_dataset/MPD_events/event_188_
# Processing: ./MPD_dataset/MPD_events/event_189_
# Processing: ./MPD_dataset/MPD_events/event_190_
# Processing: ./MPD_dataset/MPD_events/event_191_
# Processing: ./MPD_dataset/MPD_events/event_192_
# Processing: ./MPD_dataset/MPD_events/event_193_
# Processing: ./MPD_dataset/MPD_events/event_194_
# Processing: ./MPD_dataset/MPD_events/event_195_
# Processing: ./MPD_dataset/MPD_events/event_196_
# Processing: ./MPD_dataset/MPD_events/event_197_
# Processing: ./MPD_dataset/MPD_events/event_198_
# Processing: ./MPD_dataset/MPD_events/event_199_
# Processing: ./MPD_dataset/MPD_events/event_200_
# Processing: ./MPD_dataset/MPD_events/event_201_
# Processing: ./MPD_dataset/MPD_events/event_202_
# Processing: ./MPD_dataset/MPD_events/event_203_
# Processing: ./MPD_dataset/MPD_events/event_204_
# Processing: ./MPD_dataset/MPD_events/event_205_
# Processing: ./MPD_dataset/MPD_events/event_206_
# Processing: ./MPD_dataset/MPD_events/event_207_
# Processing: ./MPD_dataset/MPD_events/event_208_
# Processing: ./MPD_dataset/MPD_events/event_209_
# Processing: ./MPD_dataset/MPD_events/event_210_
# Processing: ./MPD_dataset/MPD_events/event_211_
# Processing: ./MPD_dataset/MPD_events/event_212_
# Processing: ./MPD_dataset/MPD_events/event_213_
# Processing: ./MPD_dataset/MPD_events/event_214_
# Processing: ./MPD_dataset/MPD_events/event_215_
# Processing: ./MPD_dataset/MPD_events/event_216_
# Processing: ./MPD_dataset/MPD_events/event_217_
# Processing: ./MPD_dataset/MPD_events/event_218_
# Processing: ./MPD_dataset/MPD_events/event_219_
# Processing: ./MPD_dataset/MPD_events/event_220_
# Processing: ./MPD_dataset/MPD_events/event_221_
# Processing: ./MPD_dataset/MPD_events/event_222_
# Processing: ./MPD_dataset/MPD_events/event_223_
# Processing: ./MPD_dataset/MPD_events/event_224_
# Processing: ./MPD_dataset/MPD_events/event_225_
# Processing: ./MPD_dataset/MPD_events/event_226_
# Processing: ./MPD_dataset/MPD_events/event_227_
# Processing: ./MPD_dataset/MPD_events/event_228_
# Processing: ./MPD_dataset/MPD_events/event_229_
# Processing: ./MPD_dataset/MPD_events/event_230_
# Processing: ./MPD_dataset/MPD_events/event_231_
# Processing: ./MPD_dataset/MPD_events/event_232_
# Processing: ./MPD_dataset/MPD_events/event_233_
# Processing: ./MPD_dataset/MPD_events/event_234_
# Processing: ./MPD_dataset/MPD_events/event_235_
# Processing: ./MPD_dataset/MPD_events/event_236_
# Processing: ./MPD_dataset/MPD_events/event_237_
# Processing: ./MPD_dataset/MPD_events/event_238_
# Processing: ./MPD_dataset/MPD_events/event_239_
# Processing: ./MPD_dataset/MPD_events/event_240_
# Processing: ./MPD_dataset/MPD_events/event_241_
# Processing: ./MPD_dataset/MPD_events/event_242_
# Processing: ./MPD_dataset/MPD_events/event_243_
# Processing: ./MPD_dataset/MPD_events/event_244_
# Processing: ./MPD_dataset/MPD_events/event_245_
# Processing: ./MPD_dataset/MPD_events/event_246_
# Processing: ./MPD_dataset/MPD_events/event_247_
# Processing: ./MPD_dataset/MPD_events/event_248_
# Processing: ./MPD_dataset/MPD_events/event_249_
# Processing: ./MPD_dataset/MPD_events/event_250_
# Processing: ./MPD_dataset/MPD_events/event_251_
# Processing: ./MPD_dataset/MPD_events/event_252_
# Processing: ./MPD_dataset/MPD_events/event_253_
# Processing: ./MPD_dataset/MPD_events/event_254_
# Processing: ./MPD_dataset/MPD_events/event_255_
# Processing: ./MPD_dataset/MPD_events/event_256_
# Processing: ./MPD_dataset/MPD_events/event_257_
# Processing: ./MPD_dataset/MPD_events/event_258_
# Processing: ./MPD_dataset/MPD_events/event_259_
# Processing: ./MPD_dataset/MPD_events/event_260_
# Processing: ./MPD_dataset/MPD_events/event_261_
# Processing: ./MPD_dataset/MPD_events/event_262_
# Processing: ./MPD_dataset/MPD_events/event_263_
# Processing: ./MPD_dataset/MPD_events/event_264_
# Processing: ./MPD_dataset/MPD_events/event_265_
# Processing: ./MPD_dataset/MPD_events/event_266_
# Processing: ./MPD_dataset/MPD_events/event_267_
# Processing: ./MPD_dataset/MPD_events/event_268_
# Processing: ./MPD_dataset/MPD_events/event_269_
# Processing: ./MPD_dataset/MPD_events/event_270_
# Processing: ./MPD_dataset/MPD_events/event_271_
# Processing: ./MPD_dataset/MPD_events/event_272_
# Processing: ./MPD_dataset/MPD_events/event_273_
# Processing: ./MPD_dataset/MPD_events/event_274_
# Processing: ./MPD_dataset/MPD_events/event_275_
# Processing: ./MPD_dataset/MPD_events/event_276_
# Processing: ./MPD_dataset/MPD_events/event_277_
# Processing: ./MPD_dataset/MPD_events/event_278_
# Processing: ./MPD_dataset/MPD_events/event_279_
# Processing: ./MPD_dataset/MPD_events/event_280_
# Processing: ./MPD_dataset/MPD_events/event_281_
# Processing: ./MPD_dataset/MPD_events/event_282_
# Processing: ./MPD_dataset/MPD_events/event_283_
# Processing: ./MPD_dataset/MPD_events/event_284_
# Processing: ./MPD_dataset/MPD_events/event_285_
# Processing: ./MPD_dataset/MPD_events/event_286_
# Processing: ./MPD_dataset/MPD_events/event_287_
# Processing: ./MPD_dataset/MPD_events/event_288_
# Processing: ./MPD_dataset/MPD_events/event_289_
# Processing: ./MPD_dataset/MPD_events/event_290_
# Processing: ./MPD_dataset/MPD_events/event_291_
# Processing: ./MPD_dataset/MPD_events/event_292_
# Processing: ./MPD_dataset/MPD_events/event_293_
# Processing: ./MPD_dataset/MPD_events/event_294_
# Processing: ./MPD_dataset/MPD_events/event_295_
# Processing: ./MPD_dataset/MPD_events/event_296_
# Processing: ./MPD_dataset/MPD_events/event_297_
# Processing: ./MPD_dataset/MPD_events/event_298_
# Processing: ./MPD_dataset/MPD_events/event_299_
# Processing: ./MPD_dataset/MPD_events/event_300_
# Processing: ./MPD_dataset/MPD_events/event_301_
# Processing: ./MPD_dataset/MPD_events/event_302_
# Processing: ./MPD_dataset/MPD_events/event_303_
# Processing: ./MPD_dataset/MPD_events/event_304_
# Processing: ./MPD_dataset/MPD_events/event_305_
# Processing: ./MPD_dataset/MPD_events/event_306_
# Processing: ./MPD_dataset/MPD_events/event_307_
# Processing: ./MPD_dataset/MPD_events/event_308_
# Processing: ./MPD_dataset/MPD_events/event_309_
# Processing: ./MPD_dataset/MPD_events/event_310_
# Processing: ./MPD_dataset/MPD_events/event_311_
# Processing: ./MPD_dataset/MPD_events/event_312_
# Processing: ./MPD_dataset/MPD_events/event_313_
# Processing: ./MPD_dataset/MPD_events/event_314_
# Processing: ./MPD_dataset/MPD_events/event_315_
# Processing: ./MPD_dataset/MPD_events/event_316_
# Processing: ./MPD_dataset/MPD_events/event_317_
# Processing: ./MPD_dataset/MPD_events/event_318_
# Processing: ./MPD_dataset/MPD_events/event_319_
# Processing: ./MPD_dataset/MPD_events/event_320_
# Processing: ./MPD_dataset/MPD_events/event_321_
# Processing: ./MPD_dataset/MPD_events/event_322_
# Processing: ./MPD_dataset/MPD_events/event_323_
# Processing: ./MPD_dataset/MPD_events/event_324_
# Processing: ./MPD_dataset/MPD_events/event_325_
# Processing: ./MPD_dataset/MPD_events/event_326_
# Processing: ./MPD_dataset/MPD_events/event_327_
# Processing: ./MPD_dataset/MPD_events/event_328_
# Processing: ./MPD_dataset/MPD_events/event_329_
# Processing: ./MPD_dataset/MPD_events/event_330_
# Processing: ./MPD_dataset/MPD_events/event_331_
# Processing: ./MPD_dataset/MPD_events/event_332_
# Processing: ./MPD_dataset/MPD_events/event_333_
# Processing: ./MPD_dataset/MPD_events/event_334_
# Processing: ./MPD_dataset/MPD_events/event_335_
# Processing: ./MPD_dataset/MPD_events/event_336_
# Processing: ./MPD_dataset/MPD_events/event_337_
# Processing: ./MPD_dataset/MPD_events/event_338_
# Processing: ./MPD_dataset/MPD_events/event_339_
# Processing: ./MPD_dataset/MPD_events/event_340_
# Processing: ./MPD_dataset/MPD_events/event_341_
# Processing: ./MPD_dataset/MPD_events/event_342_
# Processing: ./MPD_dataset/MPD_events/event_343_
# Processing: ./MPD_dataset/MPD_events/event_344_
# Processing: ./MPD_dataset/MPD_events/event_345_
# Processing: ./MPD_dataset/MPD_events/event_346_
# Processing: ./MPD_dataset/MPD_events/event_347_
# Processing: ./MPD_dataset/MPD_events/event_348_
# Processing: ./MPD_dataset/MPD_events/event_349_
# Processing: ./MPD_dataset/MPD_events/event_350_
# Processing: ./MPD_dataset/MPD_events/event_351_
# Processing: ./MPD_dataset/MPD_events/event_352_
# Processing: ./MPD_dataset/MPD_events/event_353_
# Processing: ./MPD_dataset/MPD_events/event_354_
# Processing: ./MPD_dataset/MPD_events/event_355_
# Processing: ./MPD_dataset/MPD_events/event_356_
# Processing: ./MPD_dataset/MPD_events/event_357_
# Processing: ./MPD_dataset/MPD_events/event_358_
# Processing: ./MPD_dataset/MPD_events/event_359_
# Processing: ./MPD_dataset/MPD_events/event_360_
# Processing: ./MPD_dataset/MPD_events/event_361_
# Processing: ./MPD_dataset/MPD_events/event_362_
# Processing: ./MPD_dataset/MPD_events/event_363_
# Processing: ./MPD_dataset/MPD_events/event_364_
# Processing: ./MPD_dataset/MPD_events/event_365_
# Processing: ./MPD_dataset/MPD_events/event_366_
# Processing: ./MPD_dataset/MPD_events/event_367_
# Processing: ./MPD_dataset/MPD_events/event_368_
# Processing: ./MPD_dataset/MPD_events/event_369_
# Processing: ./MPD_dataset/MPD_events/event_370_
# Processing: ./MPD_dataset/MPD_events/event_371_
# Processing: ./MPD_dataset/MPD_events/event_372_
# Processing: ./MPD_dataset/MPD_events/event_373_
# Processing: ./MPD_dataset/MPD_events/event_374_
# Processing: ./MPD_dataset/MPD_events/event_375_
# Processing: ./MPD_dataset/MPD_events/event_376_
# Processing: ./MPD_dataset/MPD_events/event_377_
# Processing: ./MPD_dataset/MPD_events/event_378_
# Processing: ./MPD_dataset/MPD_events/event_379_
# Processing: ./MPD_dataset/MPD_events/event_380_
# Processing: ./MPD_dataset/MPD_events/event_381_
# Processing: ./MPD_dataset/MPD_events/event_382_
# Processing: ./MPD_dataset/MPD_events/event_383_
# Processing: ./MPD_dataset/MPD_events/event_384_
# Processing: ./MPD_dataset/MPD_events/event_385_
# Processing: ./MPD_dataset/MPD_events/event_386_
# Processing: ./MPD_dataset/MPD_events/event_387_
# Processing: ./MPD_dataset/MPD_events/event_388_
# Processing: ./MPD_dataset/MPD_events/event_389_
# Processing: ./MPD_dataset/MPD_events/event_390_
# Processing: ./MPD_dataset/MPD_events/event_391_
# Processing: ./MPD_dataset/MPD_events/event_392_
# Processing: ./MPD_dataset/MPD_events/event_393_
# Processing: ./MPD_dataset/MPD_events/event_394_
# Processing: ./MPD_dataset/MPD_events/event_395_
# Processing: ./MPD_dataset/MPD_events/event_396_
# Processing: ./MPD_dataset/MPD_events/event_397_
# Processing: ./MPD_dataset/MPD_events/event_398_
# Processing: ./MPD_dataset/MPD_events/event_399_
# Processing: ./MPD_dataset/MPD_events/event_400_
# Processing: ./MPD_dataset/MPD_events/event_401_
# Processing: ./MPD_dataset/MPD_events/event_402_
# Processing: ./MPD_dataset/MPD_events/event_403_
# Processing: ./MPD_dataset/MPD_events/event_404_
# Processing: ./MPD_dataset/MPD_events/event_405_
# Processing: ./MPD_dataset/MPD_events/event_406_
# Processing: ./MPD_dataset/MPD_events/event_407_
# Processing: ./MPD_dataset/MPD_events/event_408_
# Processing: ./MPD_dataset/MPD_events/event_409_
# Processing: ./MPD_dataset/MPD_events/event_410_
# Processing: ./MPD_dataset/MPD_events/event_411_
# Processing: ./MPD_dataset/MPD_events/event_412_
# Processing: ./MPD_dataset/MPD_events/event_413_
# Processing: ./MPD_dataset/MPD_events/event_414_
# Processing: ./MPD_dataset/MPD_events/event_415_
# Processing: ./MPD_dataset/MPD_events/event_416_
# Processing: ./MPD_dataset/MPD_events/event_417_
# Processing: ./MPD_dataset/MPD_events/event_418_
# Processing: ./MPD_dataset/MPD_events/event_419_
# Processing: ./MPD_dataset/MPD_events/event_420_
# Processing: ./MPD_dataset/MPD_events/event_421_
# Processing: ./MPD_dataset/MPD_events/event_422_
# Processing: ./MPD_dataset/MPD_events/event_423_
# Processing: ./MPD_dataset/MPD_events/event_424_
# Processing: ./MPD_dataset/MPD_events/event_425_
# Processing: ./MPD_dataset/MPD_events/event_426_
# Processing: ./MPD_dataset/MPD_events/event_427_
# Processing: ./MPD_dataset/MPD_events/event_428_
# Processing: ./MPD_dataset/MPD_events/event_429_
# Processing: ./MPD_dataset/MPD_events/event_430_
# Processing: ./MPD_dataset/MPD_events/event_431_
# Processing: ./MPD_dataset/MPD_events/event_432_
# Processing: ./MPD_dataset/MPD_events/event_433_
# Processing: ./MPD_dataset/MPD_events/event_434_
# Processing: ./MPD_dataset/MPD_events/event_435_
# Processing: ./MPD_dataset/MPD_events/event_436_
# Processing: ./MPD_dataset/MPD_events/event_437_
# Processing: ./MPD_dataset/MPD_events/event_438_
# Processing: ./MPD_dataset/MPD_events/event_439_
# Processing: ./MPD_dataset/MPD_events/event_440_
# Processing: ./MPD_dataset/MPD_events/event_441_
# Processing: ./MPD_dataset/MPD_events/event_442_
# Processing: ./MPD_dataset/MPD_events/event_443_
# Processing: ./MPD_dataset/MPD_events/event_444_
# Processing: ./MPD_dataset/MPD_events/event_445_
# Processing: ./MPD_dataset/MPD_events/event_446_
# Processing: ./MPD_dataset/MPD_events/event_447_
# Processing: ./MPD_dataset/MPD_events/event_448_
# Processing: ./MPD_dataset/MPD_events/event_449_
# Processing: ./MPD_dataset/MPD_events/event_450_
# Processing: ./MPD_dataset/MPD_events/event_451_
# Processing: ./MPD_dataset/MPD_events/event_452_
# Processing: ./MPD_dataset/MPD_events/event_453_
# Processing: ./MPD_dataset/MPD_events/event_454_
# Processing: ./MPD_dataset/MPD_events/event_455_
# Processing: ./MPD_dataset/MPD_events/event_456_
# Processing: ./MPD_dataset/MPD_events/event_457_
# Processing: ./MPD_dataset/MPD_events/event_458_
# Processing: ./MPD_dataset/MPD_events/event_459_
# Processing: ./MPD_dataset/MPD_events/event_460_
# Processing: ./MPD_dataset/MPD_events/event_461_
# Processing: ./MPD_dataset/MPD_events/event_462_
# Processing: ./MPD_dataset/MPD_events/event_463_
# Processing: ./MPD_dataset/MPD_events/event_464_
# Processing: ./MPD_dataset/MPD_events/event_465_
# Processing: ./MPD_dataset/MPD_events/event_466_
# Processing: ./MPD_dataset/MPD_events/event_467_
# Processing: ./MPD_dataset/MPD_events/event_468_
# Processing: ./MPD_dataset/MPD_events/event_469_
# Processing: ./MPD_dataset/MPD_events/event_470_
# Processing: ./MPD_dataset/MPD_events/event_471_
# Processing: ./MPD_dataset/MPD_events/event_472_
# Processing: ./MPD_dataset/MPD_events/event_473_
# Processing: ./MPD_dataset/MPD_events/event_474_
# Processing: ./MPD_dataset/MPD_events/event_475_
# Processing: ./MPD_dataset/MPD_events/event_476_
# Processing: ./MPD_dataset/MPD_events/event_477_
# Processing: ./MPD_dataset/MPD_events/event_478_
# Processing: ./MPD_dataset/MPD_events/event_479_
# Processing: ./MPD_dataset/MPD_events/event_480_
# Processing: ./MPD_dataset/MPD_events/event_481_
# Processing: ./MPD_dataset/MPD_events/event_482_
# Processing: ./MPD_dataset/MPD_events/event_483_
# Processing: ./MPD_dataset/MPD_events/event_484_
# Processing: ./MPD_dataset/MPD_events/event_485_
# Processing: ./MPD_dataset/MPD_events/event_486_
# Processing: ./MPD_dataset/MPD_events/event_487_
# Processing: ./MPD_dataset/MPD_events/event_488_
# Processing: ./MPD_dataset/MPD_events/event_489_
# Processing: ./MPD_dataset/MPD_events/event_490_
# Processing: ./MPD_dataset/MPD_events/event_491_
# Processing: ./MPD_dataset/MPD_events/event_492_
# Processing: ./MPD_dataset/MPD_events/event_493_
# Processing: ./MPD_dataset/MPD_events/event_494_
# Processing: ./MPD_dataset/MPD_events/event_495_
# Processing: ./MPD_dataset/MPD_events/event_496_
# Processing: ./MPD_dataset/MPD_events/event_497_
# Processing: ./MPD_dataset/MPD_events/event_498_
# Processing: ./MPD_dataset/MPD_events/event_499_
# Processing: ./MPD_dataset/MPD_events/event_500_
# Processing: ./MPD_dataset/MPD_events/event_501_
# Processing: ./MPD_dataset/MPD_events/event_502_
# Processing: ./MPD_dataset/MPD_events/event_503_
# Processing: ./MPD_dataset/MPD_events/event_504_
# Processing: ./MPD_dataset/MPD_events/event_505_
# Processing: ./MPD_dataset/MPD_events/event_506_
# Processing: ./MPD_dataset/MPD_events/event_507_
# Processing: ./MPD_dataset/MPD_events/event_508_
# Processing: ./MPD_dataset/MPD_events/event_509_
# Processing: ./MPD_dataset/MPD_events/event_510_
# Processing: ./MPD_dataset/MPD_events/event_511_
# Processing: ./MPD_dataset/MPD_events/event_512_
# Processing: ./MPD_dataset/MPD_events/event_513_
# Processing: ./MPD_dataset/MPD_events/event_514_
# Processing: ./MPD_dataset/MPD_events/event_515_
# Processing: ./MPD_dataset/MPD_events/event_516_
# Processing: ./MPD_dataset/MPD_events/event_517_
# Processing: ./MPD_dataset/MPD_events/event_518_
# Processing: ./MPD_dataset/MPD_events/event_519_
# Processing: ./MPD_dataset/MPD_events/event_520_
# Processing: ./MPD_dataset/MPD_events/event_521_
# Processing: ./MPD_dataset/MPD_events/event_522_
# Processing: ./MPD_dataset/MPD_events/event_523_
# Processing: ./MPD_dataset/MPD_events/event_524_
# Processing: ./MPD_dataset/MPD_events/event_525_
# Processing: ./MPD_dataset/MPD_events/event_526_
# Processing: ./MPD_dataset/MPD_events/event_527_
# Processing: ./MPD_dataset/MPD_events/event_528_
# Processing: ./MPD_dataset/MPD_events/event_529_
# Processing: ./MPD_dataset/MPD_events/event_530_
# Processing: ./MPD_dataset/MPD_events/event_531_
# Processing: ./MPD_dataset/MPD_events/event_532_
# Processing: ./MPD_dataset/MPD_events/event_533_
# Processing: ./MPD_dataset/MPD_events/event_534_
# Processing: ./MPD_dataset/MPD_events/event_535_
# Processing: ./MPD_dataset/MPD_events/event_536_
# Processing: ./MPD_dataset/MPD_events/event_537_
# Processing: ./MPD_dataset/MPD_events/event_538_
# Processing: ./MPD_dataset/MPD_events/event_539_
# Processing: ./MPD_dataset/MPD_events/event_540_
# Processing: ./MPD_dataset/MPD_events/event_541_
# Processing: ./MPD_dataset/MPD_events/event_542_
# Processing: ./MPD_dataset/MPD_events/event_543_
# Processing: ./MPD_dataset/MPD_events/event_544_
# Processing: ./MPD_dataset/MPD_events/event_545_
# Processing: ./MPD_dataset/MPD_events/event_546_
# Processing: ./MPD_dataset/MPD_events/event_547_
# Processing: ./MPD_dataset/MPD_events/event_548_
# Processing: ./MPD_dataset/MPD_events/event_549_
# Processing: ./MPD_dataset/MPD_events/event_550_
# Processing: ./MPD_dataset/MPD_events/event_551_
# Processing: ./MPD_dataset/MPD_events/event_552_
# Processing: ./MPD_dataset/MPD_events/event_553_
# Processing: ./MPD_dataset/MPD_events/event_554_
# Processing: ./MPD_dataset/MPD_events/event_555_
# Processing: ./MPD_dataset/MPD_events/event_556_
# Processing: ./MPD_dataset/MPD_events/event_557_
# Processing: ./MPD_dataset/MPD_events/event_558_
# Processing: ./MPD_dataset/MPD_events/event_559_
# Processing: ./MPD_dataset/MPD_events/event_560_
# Processing: ./MPD_dataset/MPD_events/event_561_
# Processing: ./MPD_dataset/MPD_events/event_562_
# Processing: ./MPD_dataset/MPD_events/event_563_
# Processing: ./MPD_dataset/MPD_events/event_564_
# Processing: ./MPD_dataset/MPD_events/event_565_
# Processing: ./MPD_dataset/MPD_events/event_566_
# Processing: ./MPD_dataset/MPD_events/event_567_
# Processing: ./MPD_dataset/MPD_events/event_568_
# Processing: ./MPD_dataset/MPD_events/event_569_
# Processing: ./MPD_dataset/MPD_events/event_570_
# Processing: ./MPD_dataset/MPD_events/event_571_
# Processing: ./MPD_dataset/MPD_events/event_572_
# Processing: ./MPD_dataset/MPD_events/event_573_
# Processing: ./MPD_dataset/MPD_events/event_574_
# Processing: ./MPD_dataset/MPD_events/event_575_
# Processing: ./MPD_dataset/MPD_events/event_576_
# Processing: ./MPD_dataset/MPD_events/event_577_
# Processing: ./MPD_dataset/MPD_events/event_578_
# Processing: ./MPD_dataset/MPD_events/event_579_
# Processing: ./MPD_dataset/MPD_events/event_580_
# Processing: ./MPD_dataset/MPD_events/event_581_
# Processing: ./MPD_dataset/MPD_events/event_582_
# Processing: ./MPD_dataset/MPD_events/event_583_
# Processing: ./MPD_dataset/MPD_events/event_584_
# Processing: ./MPD_dataset/MPD_events/event_585_
# Processing: ./MPD_dataset/MPD_events/event_586_
# Processing: ./MPD_dataset/MPD_events/event_587_
# Processing: ./MPD_dataset/MPD_events/event_588_
# Processing: ./MPD_dataset/MPD_events/event_589_
# Processing: ./MPD_dataset/MPD_events/event_590_
# Processing: ./MPD_dataset/MPD_events/event_591_
# Processing: ./MPD_dataset/MPD_events/event_592_
# Processing: ./MPD_dataset/MPD_events/event_593_
# Processing: ./MPD_dataset/MPD_events/event_594_
# Processing: ./MPD_dataset/MPD_events/event_595_
# Processing: ./MPD_dataset/MPD_events/event_596_
# Processing: ./MPD_dataset/MPD_events/event_597_
# Processing: ./MPD_dataset/MPD_events/event_598_
# Processing: ./MPD_dataset/MPD_events/event_599_
# Processing: ./MPD_dataset/MPD_events/event_600_
# Processing: ./MPD_dataset/MPD_events/event_601_
# Processing: ./MPD_dataset/MPD_events/event_602_
# Processing: ./MPD_dataset/MPD_events/event_603_
# Processing: ./MPD_dataset/MPD_events/event_604_
# Processing: ./MPD_dataset/MPD_events/event_605_
# Processing: ./MPD_dataset/MPD_events/event_606_
# Processing: ./MPD_dataset/MPD_events/event_607_
# Processing: ./MPD_dataset/MPD_events/event_608_
# Processing: ./MPD_dataset/MPD_events/event_609_
# Processing: ./MPD_dataset/MPD_events/event_610_
# Processing: ./MPD_dataset/MPD_events/event_611_
# Processing: ./MPD_dataset/MPD_events/event_612_
# Processing: ./MPD_dataset/MPD_events/event_613_
# Processing: ./MPD_dataset/MPD_events/event_614_
# Processing: ./MPD_dataset/MPD_events/event_615_
# Processing: ./MPD_dataset/MPD_events/event_616_
# Processing: ./MPD_dataset/MPD_events/event_617_
# Processing: ./MPD_dataset/MPD_events/event_618_
# Processing: ./MPD_dataset/MPD_events/event_619_
# Processing: ./MPD_dataset/MPD_events/event_620_
# Processing: ./MPD_dataset/MPD_events/event_621_
# Processing: ./MPD_dataset/MPD_events/event_622_
# Processing: ./MPD_dataset/MPD_events/event_623_
# Processing: ./MPD_dataset/MPD_events/event_624_
# Processing: ./MPD_dataset/MPD_events/event_625_
# Processing: ./MPD_dataset/MPD_events/event_626_
# Processing: ./MPD_dataset/MPD_events/event_627_
# Processing: ./MPD_dataset/MPD_events/event_628_
# Processing: ./MPD_dataset/MPD_events/event_629_
# Processing: ./MPD_dataset/MPD_events/event_630_
# Processing: ./MPD_dataset/MPD_events/event_631_
# Processing: ./MPD_dataset/MPD_events/event_632_
# Processing: ./MPD_dataset/MPD_events/event_633_
# Processing: ./MPD_dataset/MPD_events/event_634_
# Processing: ./MPD_dataset/MPD_events/event_635_
# Processing: ./MPD_dataset/MPD_events/event_636_
# Processing: ./MPD_dataset/MPD_events/event_637_
# Processing: ./MPD_dataset/MPD_events/event_638_
# Processing: ./MPD_dataset/MPD_events/event_639_
# Processing: ./MPD_dataset/MPD_events/event_640_
# Processing: ./MPD_dataset/MPD_events/event_641_
# Processing: ./MPD_dataset/MPD_events/event_642_
# Processing: ./MPD_dataset/MPD_events/event_643_
# Processing: ./MPD_dataset/MPD_events/event_644_
# Processing: ./MPD_dataset/MPD_events/event_645_
# Processing: ./MPD_dataset/MPD_events/event_646_
# Processing: ./MPD_dataset/MPD_events/event_647_
# Processing: ./MPD_dataset/MPD_events/event_648_
# Processing: ./MPD_dataset/MPD_events/event_649_
# Processing: ./MPD_dataset/MPD_events/event_650_
# Processing: ./MPD_dataset/MPD_events/event_651_
# Processing: ./MPD_dataset/MPD_events/event_652_
# Processing: ./MPD_dataset/MPD_events/event_653_
# Processing: ./MPD_dataset/MPD_events/event_654_
# Processing: ./MPD_dataset/MPD_events/event_655_
# Processing: ./MPD_dataset/MPD_events/event_656_
# Processing: ./MPD_dataset/MPD_events/event_657_
# Processing: ./MPD_dataset/MPD_events/event_658_
# Processing: ./MPD_dataset/MPD_events/event_659_
# Processing: ./MPD_dataset/MPD_events/event_660_
# Processing: ./MPD_dataset/MPD_events/event_661_
# Processing: ./MPD_dataset/MPD_events/event_662_
# Processing: ./MPD_dataset/MPD_events/event_663_
# Processing: ./MPD_dataset/MPD_events/event_664_
# Processing: ./MPD_dataset/MPD_events/event_665_
# Processing: ./MPD_dataset/MPD_events/event_666_
# Processing: ./MPD_dataset/MPD_events/event_667_
# Processing: ./MPD_dataset/MPD_events/event_668_
# Processing: ./MPD_dataset/MPD_events/event_669_
# Processing: ./MPD_dataset/MPD_events/event_670_
# Processing: ./MPD_dataset/MPD_events/event_671_
# Processing: ./MPD_dataset/MPD_events/event_672_
# Processing: ./MPD_dataset/MPD_events/event_673_
# Processing: ./MPD_dataset/MPD_events/event_674_
# Processing: ./MPD_dataset/MPD_events/event_675_
# Processing: ./MPD_dataset/MPD_events/event_676_
# Processing: ./MPD_dataset/MPD_events/event_677_
# Processing: ./MPD_dataset/MPD_events/event_678_
# Processing: ./MPD_dataset/MPD_events/event_679_
# Processing: ./MPD_dataset/MPD_events/event_680_
# Processing: ./MPD_dataset/MPD_events/event_681_
# Processing: ./MPD_dataset/MPD_events/event_682_
# Processing: ./MPD_dataset/MPD_events/event_683_
# Processing: ./MPD_dataset/MPD_events/event_684_
# Processing: ./MPD_dataset/MPD_events/event_685_
# Processing: ./MPD_dataset/MPD_events/event_686_
# Processing: ./MPD_dataset/MPD_events/event_687_
# Processing: ./MPD_dataset/MPD_events/event_688_
# Processing: ./MPD_dataset/MPD_events/event_689_
# Processing: ./MPD_dataset/MPD_events/event_690_
# Processing: ./MPD_dataset/MPD_events/event_691_
# Processing: ./MPD_dataset/MPD_events/event_692_
# Processing: ./MPD_dataset/MPD_events/event_693_
# Processing: ./MPD_dataset/MPD_events/event_694_
# Processing: ./MPD_dataset/MPD_events/event_695_
# Processing: ./MPD_dataset/MPD_events/event_696_
# Processing: ./MPD_dataset/MPD_events/event_697_
# Processing: ./MPD_dataset/MPD_events/event_698_
# Processing: ./MPD_dataset/MPD_events/event_699_
# Processing: ./MPD_dataset/MPD_events/event_700_
# Processing: ./MPD_dataset/MPD_events/event_701_
# Processing: ./MPD_dataset/MPD_events/event_702_
# Processing: ./MPD_dataset/MPD_events/event_703_
# Processing: ./MPD_dataset/MPD_events/event_704_
# Processing: ./MPD_dataset/MPD_events/event_705_
# Processing: ./MPD_dataset/MPD_events/event_706_
# Processing: ./MPD_dataset/MPD_events/event_707_
# Processing: ./MPD_dataset/MPD_events/event_708_
# Processing: ./MPD_dataset/MPD_events/event_709_
# Processing: ./MPD_dataset/MPD_events/event_710_
# Processing: ./MPD_dataset/MPD_events/event_711_
# Processing: ./MPD_dataset/MPD_events/event_712_
# Processing: ./MPD_dataset/MPD_events/event_713_
# Processing: ./MPD_dataset/MPD_events/event_714_
# Processing: ./MPD_dataset/MPD_events/event_715_
# Processing: ./MPD_dataset/MPD_events/event_716_
# Processing: ./MPD_dataset/MPD_events/event_717_
# Processing: ./MPD_dataset/MPD_events/event_718_
# Processing: ./MPD_dataset/MPD_events/event_719_
# Processing: ./MPD_dataset/MPD_events/event_720_
# Processing: ./MPD_dataset/MPD_events/event_721_
# Processing: ./MPD_dataset/MPD_events/event_722_
# Processing: ./MPD_dataset/MPD_events/event_723_
# Processing: ./MPD_dataset/MPD_events/event_724_
# Processing: ./MPD_dataset/MPD_events/event_725_
# Processing: ./MPD_dataset/MPD_events/event_726_
# Processing: ./MPD_dataset/MPD_events/event_727_
# Processing: ./MPD_dataset/MPD_events/event_728_
# Processing: ./MPD_dataset/MPD_events/event_729_
# Processing: ./MPD_dataset/MPD_events/event_730_
# Processing: ./MPD_dataset/MPD_events/event_731_
# Processing: ./MPD_dataset/MPD_events/event_732_
# Processing: ./MPD_dataset/MPD_events/event_733_
# Processing: ./MPD_dataset/MPD_events/event_734_
# Processing: ./MPD_dataset/MPD_events/event_735_
# Processing: ./MPD_dataset/MPD_events/event_736_
# Processing: ./MPD_dataset/MPD_events/event_737_
# Processing: ./MPD_dataset/MPD_events/event_738_
# Processing: ./MPD_dataset/MPD_events/event_739_
# Processing: ./MPD_dataset/MPD_events/event_740_
# Processing: ./MPD_dataset/MPD_events/event_741_
# Processing: ./MPD_dataset/MPD_events/event_742_
# Processing: ./MPD_dataset/MPD_events/event_743_
# Processing: ./MPD_dataset/MPD_events/event_744_
# Processing: ./MPD_dataset/MPD_events/event_745_
# Processing: ./MPD_dataset/MPD_events/event_746_
# Processing: ./MPD_dataset/MPD_events/event_747_
# Processing: ./MPD_dataset/MPD_events/event_748_
# Processing: ./MPD_dataset/MPD_events/event_749_
# Processing: ./MPD_dataset/MPD_events/event_750_
# Processing: ./MPD_dataset/MPD_events/event_751_
# Processing: ./MPD_dataset/MPD_events/event_752_
# Processing: ./MPD_dataset/MPD_events/event_753_
# Processing: ./MPD_dataset/MPD_events/event_754_
# Processing: ./MPD_dataset/MPD_events/event_755_
# Processing: ./MPD_dataset/MPD_events/event_756_
# Processing: ./MPD_dataset/MPD_events/event_757_
# Processing: ./MPD_dataset/MPD_events/event_758_
# Processing: ./MPD_dataset/MPD_events/event_759_
# Processing: ./MPD_dataset/MPD_events/event_760_
# Processing: ./MPD_dataset/MPD_events/event_761_
# Processing: ./MPD_dataset/MPD_events/event_762_
# Processing: ./MPD_dataset/MPD_events/event_763_
# Processing: ./MPD_dataset/MPD_events/event_764_
# Processing: ./MPD_dataset/MPD_events/event_765_
# Processing: ./MPD_dataset/MPD_events/event_766_
# Processing: ./MPD_dataset/MPD_events/event_767_
# Processing: ./MPD_dataset/MPD_events/event_768_
# Processing: ./MPD_dataset/MPD_events/event_769_
# Processing: ./MPD_dataset/MPD_events/event_770_
# Processing: ./MPD_dataset/MPD_events/event_771_
# Processing: ./MPD_dataset/MPD_events/event_772_
# Processing: ./MPD_dataset/MPD_events/event_773_
# Processing: ./MPD_dataset/MPD_events/event_774_
# Processing: ./MPD_dataset/MPD_events/event_775_
# Processing: ./MPD_dataset/MPD_events/event_776_
# Processing: ./MPD_dataset/MPD_events/event_777_
# Processing: ./MPD_dataset/MPD_events/event_778_
# Processing: ./MPD_dataset/MPD_events/event_779_
# Processing: ./MPD_dataset/MPD_events/event_780_
# Processing: ./MPD_dataset/MPD_events/event_781_
# Processing: ./MPD_dataset/MPD_events/event_782_
# Processing: ./MPD_dataset/MPD_events/event_783_
# Processing: ./MPD_dataset/MPD_events/event_784_
# Processing: ./MPD_dataset/MPD_events/event_785_
# Processing: ./MPD_dataset/MPD_events/event_786_
# Processing: ./MPD_dataset/MPD_events/event_787_
# Processing: ./MPD_dataset/MPD_events/event_788_
# Processing: ./MPD_dataset/MPD_events/event_789_
# Processing: ./MPD_dataset/MPD_events/event_790_
# Processing: ./MPD_dataset/MPD_events/event_791_
# Processing: ./MPD_dataset/MPD_events/event_792_
# Processing: ./MPD_dataset/MPD_events/event_793_
# Processing: ./MPD_dataset/MPD_events/event_794_
# Processing: ./MPD_dataset/MPD_events/event_795_
# Processing: ./MPD_dataset/MPD_events/event_796_
# Processing: ./MPD_dataset/MPD_events/event_797_
# Processing: ./MPD_dataset/MPD_events/event_798_
# Processing: ./MPD_dataset/MPD_events/event_799_
# Processing: ./MPD_dataset/MPD_events/event_800_
# Processing: ./MPD_dataset/MPD_events/event_801_
# Processing: ./MPD_dataset/MPD_events/event_802_
# Processing: ./MPD_dataset/MPD_events/event_803_
# Processing: ./MPD_dataset/MPD_events/event_804_
# Processing: ./MPD_dataset/MPD_events/event_805_
# Processing: ./MPD_dataset/MPD_events/event_806_
# Processing: ./MPD_dataset/MPD_events/event_807_
# Processing: ./MPD_dataset/MPD_events/event_808_
# Processing: ./MPD_dataset/MPD_events/event_809_
# Processing: ./MPD_dataset/MPD_events/event_810_
# Processing: ./MPD_dataset/MPD_events/event_811_
# Processing: ./MPD_dataset/MPD_events/event_812_
# Processing: ./MPD_dataset/MPD_events/event_813_
# Processing: ./MPD_dataset/MPD_events/event_814_
# Processing: ./MPD_dataset/MPD_events/event_815_
# Processing: ./MPD_dataset/MPD_events/event_816_
# Processing: ./MPD_dataset/MPD_events/event_817_
# Processing: ./MPD_dataset/MPD_events/event_818_
# Processing: ./MPD_dataset/MPD_events/event_819_
# Processing: ./MPD_dataset/MPD_events/event_820_
# Processing: ./MPD_dataset/MPD_events/event_821_
# Processing: ./MPD_dataset/MPD_events/event_822_
# Processing: ./MPD_dataset/MPD_events/event_823_
# Processing: ./MPD_dataset/MPD_events/event_824_
# Processing: ./MPD_dataset/MPD_events/event_825_
# Processing: ./MPD_dataset/MPD_events/event_826_
# Processing: ./MPD_dataset/MPD_events/event_827_
# Processing: ./MPD_dataset/MPD_events/event_828_
# Processing: ./MPD_dataset/MPD_events/event_829_
# Processing: ./MPD_dataset/MPD_events/event_830_
# Processing: ./MPD_dataset/MPD_events/event_831_
# Processing: ./MPD_dataset/MPD_events/event_832_
# Processing: ./MPD_dataset/MPD_events/event_833_
# Processing: ./MPD_dataset/MPD_events/event_834_
# Processing: ./MPD_dataset/MPD_events/event_835_
# Processing: ./MPD_dataset/MPD_events/event_836_
# Processing: ./MPD_dataset/MPD_events/event_837_
# Processing: ./MPD_dataset/MPD_events/event_838_
# Processing: ./MPD_dataset/MPD_events/event_839_
# Processing: ./MPD_dataset/MPD_events/event_840_
# Processing: ./MPD_dataset/MPD_events/event_841_
# Processing: ./MPD_dataset/MPD_events/event_842_
# Processing: ./MPD_dataset/MPD_events/event_843_
# Processing: ./MPD_dataset/MPD_events/event_844_
# Processing: ./MPD_dataset/MPD_events/event_845_
# Processing: ./MPD_dataset/MPD_events/event_846_
# Processing: ./MPD_dataset/MPD_events/event_847_
# Processing: ./MPD_dataset/MPD_events/event_848_
# Processing: ./MPD_dataset/MPD_events/event_849_
# Processing: ./MPD_dataset/MPD_events/event_850_
# Processing: ./MPD_dataset/MPD_events/event_851_
# Processing: ./MPD_dataset/MPD_events/event_852_
# Processing: ./MPD_dataset/MPD_events/event_853_
# Processing: ./MPD_dataset/MPD_events/event_854_
# Processing: ./MPD_dataset/MPD_events/event_855_
# Processing: ./MPD_dataset/MPD_events/event_856_
# Processing: ./MPD_dataset/MPD_events/event_857_
# Processing: ./MPD_dataset/MPD_events/event_858_
# Processing: ./MPD_dataset/MPD_events/event_859_
# Processing: ./MPD_dataset/MPD_events/event_860_
# Processing: ./MPD_dataset/MPD_events/event_861_
# Processing: ./MPD_dataset/MPD_events/event_862_
# Processing: ./MPD_dataset/MPD_events/event_863_
# Processing: ./MPD_dataset/MPD_events/event_864_
# Processing: ./MPD_dataset/MPD_events/event_865_
# Processing: ./MPD_dataset/MPD_events/event_866_
# Processing: ./MPD_dataset/MPD_events/event_867_
# Processing: ./MPD_dataset/MPD_events/event_868_
# Processing: ./MPD_dataset/MPD_events/event_869_
# Processing: ./MPD_dataset/MPD_events/event_870_
# Processing: ./MPD_dataset/MPD_events/event_871_
# Processing: ./MPD_dataset/MPD_events/event_872_
# Processing: ./MPD_dataset/MPD_events/event_873_
# Processing: ./MPD_dataset/MPD_events/event_874_
# Processing: ./MPD_dataset/MPD_events/event_875_
# Processing: ./MPD_dataset/MPD_events/event_876_
# Processing: ./MPD_dataset/MPD_events/event_877_
# Processing: ./MPD_dataset/MPD_events/event_878_
# Processing: ./MPD_dataset/MPD_events/event_879_
# Processing: ./MPD_dataset/MPD_events/event_880_
# Processing: ./MPD_dataset/MPD_events/event_881_
# Processing: ./MPD_dataset/MPD_events/event_882_
# Processing: ./MPD_dataset/MPD_events/event_883_
# Processing: ./MPD_dataset/MPD_events/event_884_
# Processing: ./MPD_dataset/MPD_events/event_885_
# Processing: ./MPD_dataset/MPD_events/event_886_
# Processing: ./MPD_dataset/MPD_events/event_887_
# Processing: ./MPD_dataset/MPD_events/event_888_
# Processing: ./MPD_dataset/MPD_events/event_889_
# Processing: ./MPD_dataset/MPD_events/event_890_
# Processing: ./MPD_dataset/MPD_events/event_891_
# Processing: ./MPD_dataset/MPD_events/event_892_
# Processing: ./MPD_dataset/MPD_events/event_893_
# Processing: ./MPD_dataset/MPD_events/event_894_
# Processing: ./MPD_dataset/MPD_events/event_895_
# Processing: ./MPD_dataset/MPD_events/event_896_
# Processing: ./MPD_dataset/MPD_events/event_897_
# Processing: ./MPD_dataset/MPD_events/event_898_
# Processing: ./MPD_dataset/MPD_events/event_899_
# Processing: ./MPD_dataset/MPD_events/event_900_
# Processing: ./MPD_dataset/MPD_events/event_901_
# Processing: ./MPD_dataset/MPD_events/event_902_
# Processing: ./MPD_dataset/MPD_events/event_903_
# Processing: ./MPD_dataset/MPD_events/event_904_
# Processing: ./MPD_dataset/MPD_events/event_905_
# Processing: ./MPD_dataset/MPD_events/event_906_
# Processing: ./MPD_dataset/MPD_events/event_907_
# Processing: ./MPD_dataset/MPD_events/event_908_
# Processing: ./MPD_dataset/MPD_events/event_909_
# Processing: ./MPD_dataset/MPD_events/event_910_
# Processing: ./MPD_dataset/MPD_events/event_911_
# Processing: ./MPD_dataset/MPD_events/event_912_
# Processing: ./MPD_dataset/MPD_events/event_913_
# Processing: ./MPD_dataset/MPD_events/event_914_
# Processing: ./MPD_dataset/MPD_events/event_915_
# Processing: ./MPD_dataset/MPD_events/event_916_
# Processing: ./MPD_dataset/MPD_events/event_917_
# Processing: ./MPD_dataset/MPD_events/event_918_
# Processing: ./MPD_dataset/MPD_events/event_919_
# Processing: ./MPD_dataset/MPD_events/event_920_
# Processing: ./MPD_dataset/MPD_events/event_921_
# Processing: ./MPD_dataset/MPD_events/event_922_
# Processing: ./MPD_dataset/MPD_events/event_923_
# Processing: ./MPD_dataset/MPD_events/event_924_
# Processing: ./MPD_dataset/MPD_events/event_925_
# Processing: ./MPD_dataset/MPD_events/event_926_
# Processing: ./MPD_dataset/MPD_events/event_927_
# Processing: ./MPD_dataset/MPD_events/event_928_
# Processing: ./MPD_dataset/MPD_events/event_929_
# Processing: ./MPD_dataset/MPD_events/event_930_
# Processing: ./MPD_dataset/MPD_events/event_931_
# Processing: ./MPD_dataset/MPD_events/event_932_
# Processing: ./MPD_dataset/MPD_events/event_933_
# Processing: ./MPD_dataset/MPD_events/event_934_
# Processing: ./MPD_dataset/MPD_events/event_935_
# Processing: ./MPD_dataset/MPD_events/event_936_
# Processing: ./MPD_dataset/MPD_events/event_937_
# Processing: ./MPD_dataset/MPD_events/event_938_
# Processing: ./MPD_dataset/MPD_events/event_939_
# Processing: ./MPD_dataset/MPD_events/event_940_
# Processing: ./MPD_dataset/MPD_events/event_941_
# Processing: ./MPD_dataset/MPD_events/event_942_
# Processing: ./MPD_dataset/MPD_events/event_943_
# Processing: ./MPD_dataset/MPD_events/event_944_
# Processing: ./MPD_dataset/MPD_events/event_945_
# Processing: ./MPD_dataset/MPD_events/event_946_
# Processing: ./MPD_dataset/MPD_events/event_947_
# Processing: ./MPD_dataset/MPD_events/event_948_
# Processing: ./MPD_dataset/MPD_events/event_949_
# Processing: ./MPD_dataset/MPD_events/event_950_
# Processing: ./MPD_dataset/MPD_events/event_951_
# Processing: ./MPD_dataset/MPD_events/event_952_
# Processing: ./MPD_dataset/MPD_events/event_953_
# Processing: ./MPD_dataset/MPD_events/event_954_
# Processing: ./MPD_dataset/MPD_events/event_955_
# Processing: ./MPD_dataset/MPD_events/event_956_
# Processing: ./MPD_dataset/MPD_events/event_957_
# Processing: ./MPD_dataset/MPD_events/event_958_
# Processing: ./MPD_dataset/MPD_events/event_959_
# Processing: ./MPD_dataset/MPD_events/event_960_
# Processing: ./MPD_dataset/MPD_events/event_961_
# Processing: ./MPD_dataset/MPD_events/event_962_
# Processing: ./MPD_dataset/MPD_events/event_963_
# Processing: ./MPD_dataset/MPD_events/event_964_
# Processing: ./MPD_dataset/MPD_events/event_965_
# Processing: ./MPD_dataset/MPD_events/event_966_
# Processing: ./MPD_dataset/MPD_events/event_967_
# Processing: ./MPD_dataset/MPD_events/event_968_
# Processing: ./MPD_dataset/MPD_events/event_969_
# Processing: ./MPD_dataset/MPD_events/event_970_
# Processing: ./MPD_dataset/MPD_events/event_971_
# Processing: ./MPD_dataset/MPD_events/event_972_
# Processing: ./MPD_dataset/MPD_events/event_973_
# Processing: ./MPD_dataset/MPD_events/event_974_
# Processing: ./MPD_dataset/MPD_events/event_975_
# Processing: ./MPD_dataset/MPD_events/event_976_
# Processing: ./MPD_dataset/MPD_events/event_977_
# Processing: ./MPD_dataset/MPD_events/event_978_
# Processing: ./MPD_dataset/MPD_events/event_979_
# Processing: ./MPD_dataset/MPD_events/event_980_
# Processing: ./MPD_dataset/MPD_events/event_981_
# Processing: ./MPD_dataset/MPD_events/event_982_
# Processing: ./MPD_dataset/MPD_events/event_983_
# Processing: ./MPD_dataset/MPD_events/event_984_
# Processing: ./MPD_dataset/MPD_events/event_985_
# Processing: ./MPD_dataset/MPD_events/event_986_
# Processing: ./MPD_dataset/MPD_events/event_987_
# Processing: ./MPD_dataset/MPD_events/event_988_
# Processing: ./MPD_dataset/MPD_events/event_989_
# Processing: ./MPD_dataset/MPD_events/event_990_
# Processing: ./MPD_dataset/MPD_events/event_991_
# Processing: ./MPD_dataset/MPD_events/event_992_
# Processing: ./MPD_dataset/MPD_events/event_993_
# Processing: ./MPD_dataset/MPD_events/event_994_
# Processing: ./MPD_dataset/MPD_events/event_995_
# Processing: ./MPD_dataset/MPD_events/event_996_
# Processing: ./MPD_dataset/MPD_events/event_997_
# Processing: ./MPD_dataset/MPD_events/event_998_
# Processing: ./MPD_dataset/MPD_events/event_999_

# %%
np.array(dphi_list).max()
# Out:
# 0.5139129699880387

# %%
plt.hist(np.array(dphi_list)[np.array(dphi_list) < 0.1], bins=100, color='blue', edgecolor='black')

plt.ylabel('Counts')
plt.xlabel('Phi')

plt.show()

# %%
np.array(dtheta_list).max()
# Out:
# 1.5707722918655396

# %%
plt.hist(np.array(dtheta_list), bins=100, color='blue', edgecolor='black')

plt.ylabel('Counts')
plt.xlabel('Theta')

plt.show()

# %%
np.array(z0_list).max()
# Out:
# 2222943.256433288

# %%
plt.hist(np.array(z0_list)[np.array(z0_list) < 500], bins=100, color='blue', edgecolor='black')

plt.ylabel('Counts')
plt.xlabel('$Z_{0}$')

plt.show()

# %%
np.array(distance_list).max()
# Out:
# 127.26983306105969

# %%
plt.hist(np.array(distance_list)[np.array(distance_list) < 15], bins=100, color='blue', edgecolor='black')

plt.ylabel('Counts')
plt.xlabel('Distance')

plt.show()

# %%
np.array(rmaxlist).max()
# Out:
# 123.17593093299519

# %%
np.array(zminlist).min()
# Out:
# -165.853

# %%
np.array(zmaxlist).max()
# Out:
# 168.646

# %%
np.array(minrowlist).min()
# Out:
# 0

# %%
np.array(maxrowlist).max()
# Out:
# 52

# %%
with plt.rc_context({'font.family': 'Nimbus Roman'}):
    plt.figure(figsize=(7, 5))
    plt.hist(particlenumlist, bins=50, color='red', edgecolor='black')
    plt.ylabel('Counts', fontsize=20)
    plt.xlabel('Particle number', fontsize=20)
    plt.xlim([60, 1070])
    plt.ylim([0, 100])
    plt.tick_params(axis='both', 
                        which='major', 
                        labelsize=18,
                        top=True,
                        bottom=True,
                        left=True,
                        right=True,
                        direction='in')
    plt.tight_layout()
    plt.show()
    #plt.savefig("Particle_number.pdf")

# %%
print(f'{len([x for x in particlenumlist if x > 400]) / len(particlenumlist) * 100:.2f}%')
# Out:
# 32.60%

# %%
sum(particlenumlist) / len(particlenumlist)
# Out:
# 337.768

# %%
with plt.rc_context({'font.family': 'Nimbus Roman'}):
    plt.figure(figsize=(7, 5))
    plt.hist(hitnumlist, bins=50, color='red', edgecolor='black')
    def format_x_ticks(x, pos):
        return f"{x / 1e4:.1f}·10$^4$"
    plt.ylabel('Counts', fontsize=20)
    plt.xlabel('Hit number', fontsize=20)
    plt.gca().xaxis.set_major_formatter(FuncFormatter(format_x_ticks))
    plt.xlim([2000, 55000])
    plt.ylim([0, 100])
    plt.tick_params(axis='both', 
                        which='major', 
                        labelsize=18,
                        top=True,
                        bottom=True,
                        left=True,
                        right=True,
                        direction='in')
    plt.tight_layout()
    plt.show()
    #plt.savefig("Hit_number.pdf")

# %%
sum(hitnumlist) / len(hitnumlist)
# Out:
# 16989.998
